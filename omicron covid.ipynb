# %%
import pandas as pd

df = pd.read_csv (r'Downloads\covid-variants.csv')
print (df)
# Out:
#         location        date         variant  num_sequences  perc_sequences  \
# 0         Angola  2020-07-06           Alpha              0             0.0
# 1         Angola  2020-07-06       B.1.1.277              0             0.0
# 2         Angola  2020-07-06       B.1.1.302              0             0.0
# 3         Angola  2020-07-06       B.1.1.519              0             0.0
# 4         Angola  2020-07-06         B.1.160              0             0.0
# ...          ...         ...             ...            ...             ...
# 100411  Zimbabwe  2021-11-01         Omicron              0             0.0
# 100412  Zimbabwe  2021-11-01   S:677H.Robin1              0             0.0
# 100413  Zimbabwe  2021-11-01  S:677P.Pelican              0             0.0
# 100414  Zimbabwe  2021-11-01          others              0             0.0
# 100415  Zimbabwe  2021-11-01         non_who              0             0.0
#
#         num_sequences_total
# ...

# %%
data_set=df

# %%
#convert the data to dataframe
df = pd.DataFrame(data_set)
df
# Out:
#         location        date         variant  num_sequences  perc_sequences  \
# 0         Angola  2020-07-06           Alpha              0             0.0
# 1         Angola  2020-07-06       B.1.1.277              0             0.0
# 2         Angola  2020-07-06       B.1.1.302              0             0.0
# 3         Angola  2020-07-06       B.1.1.519              0             0.0
# 4         Angola  2020-07-06         B.1.160              0             0.0
# ...          ...         ...             ...            ...             ...
# 100411  Zimbabwe  2021-11-01         Omicron              0             0.0
# 100412  Zimbabwe  2021-11-01   S:677H.Robin1              0             0.0
# 100413  Zimbabwe  2021-11-01  S:677P.Pelican              0             0.0
# 100414  Zimbabwe  2021-11-01          others              0             0.0
# 100415  Zimbabwe  2021-11-01         non_who              0             0.0
#
#         num_sequences_total
# ...

# %%
#list and number of countries whose data is included in the file
counts = df['location'].unique()
print(counts)
np.size(counts)
# Out:
# ['Angola' 'Argentina' 'Aruba' 'Australia' 'Austria' 'Bahrain' 'Bangladesh'
#  'Belgium' 'Belize' 'Benin' 'Bosnia and Herzegovina' 'Botswana' 'Brazil'
#  'Brunei' 'Bulgaria' 'Cambodia' 'Cameroon' 'Canada' 'Chile' 'Colombia'
#  'Costa Rica' 'Croatia' 'Curacao' 'Cyprus' 'Czechia' 'Denmark' 'Djibouti'
#  'Dominican Republic' 'Ecuador' 'Egypt' 'Estonia' 'Ethiopia' 'Fiji'
#  'Finland' 'France' 'Gambia' 'Georgia' 'Germany' 'Ghana' 'Greece'
#  'Guatemala' 'Hong Kong' 'Hungary' 'Iceland' 'India' 'Indonesia' 'Iran'
#  'Iraq' 'Ireland' 'Israel' 'Italy' 'Jamaica' 'Japan' 'Jordan' 'Kazakhstan'
#  'Kenya' 'Kosovo' 'Kuwait' 'Latvia' 'Lebanon' 'Liechtenstein' 'Lithuania'
#  'Luxembourg' 'Madagascar' 'Malawi' 'Malaysia' 'Maldives' 'Malta'
#  'Mauritius' 'Mexico' 'Moldova' 'Monaco' 'Mongolia' 'Montenegro' 'Morocco'
#  'Mozambique' 'Nepal' 'Netherlands' 'New Zealand' 'Nigeria'
#  'North Macedonia' 'Norway' 'Oman' 'Pakistan' 'Papua New Guinea'
# ...

# %%
df.head()
# Out:
#   location        date    variant  num_sequences  perc_sequences  \
# 0   Angola  2020-07-06      Alpha              0             0.0
# 1   Angola  2020-07-06  B.1.1.277              0             0.0
# 2   Angola  2020-07-06  B.1.1.302              0             0.0
# 3   Angola  2020-07-06  B.1.1.519              0             0.0
# 4   Angola  2020-07-06    B.1.160              0             0.0
#
#    num_sequences_total
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# 4                    3

# %%
df.tail()
# Out:
#         location        date         variant  num_sequences  perc_sequences  \
# 100411  Zimbabwe  2021-11-01         Omicron              0             0.0
# 100412  Zimbabwe  2021-11-01   S:677H.Robin1              0             0.0
# 100413  Zimbabwe  2021-11-01  S:677P.Pelican              0             0.0
# 100414  Zimbabwe  2021-11-01          others              0             0.0
# 100415  Zimbabwe  2021-11-01         non_who              0             0.0
#
#         num_sequences_total
# 100411                    6
# 100412                    6
# 100413                    6
# 100414                    6
# 100415                    6

# %%
##so we have 121 countries and India is at index 44
my_country = np.where(counts == ['India'])
my_country
# Out:
# (array([44], dtype=int64),)

# %%
#no of cases in each contry.
df["location"].value_counts()
# Out:
# Bangladesh        1080
# Belgium           1080
# United States     1080
# United Kingdom    1080
# France            1080
#                   ...
# Montenegro         384
# Monaco             360
# Fiji               336
# Benin              336
# Brunei             240
# Name: location, Length: 121, dtype: int64

# %%
#top 5 countries with least number of registered cases
df["location"].value_counts().sort_values()[:5].to_frame()
# Out:
#           location
# Brunei         240
# Benin          336
# Fiji           336
# Monaco         360
# Ethiopia       384

# %%
#top 5 countries with max number of registered cases
df["location"].value_counts().sort_values(ascending = False)[:5].to_frame()
# Out:
#                 location
# Bangladesh          1080
# United States       1080
# United Kingdom      1080
# France              1080
# Mexico              1080

# %%
#the range from when the data is available and from which location
first_date = pd.to_datetime(df['date']).min()
last_date = pd.to_datetime(df['date']).max()
print(f"First case registered on {first_date} at {df['location'][pd.to_datetime(df['date']).idxmin()]} ,Variant : {df['variant'][pd.to_datetime(df['date']).idxmin()]}")
print(f"Last case registered on {last_date} at {df['location'][pd.to_datetime(df['date']).idxmax()]},Variant : {df['variant'][pd.to_datetime(df['date']).idxmax()]}")
# Out:
# First case registered on 2020-05-11 00:00:00 at Argentina ,Variant : Alpha
# Last case registered on 2022-01-05 00:00:00 at Bangladesh,Variant : Alpha

# %%
#total different type of variants absorved
print(df['variant'].unique())
np.size(df['variant'].unique())
# Out:
# ['Alpha' 'B.1.1.277' 'B.1.1.302' 'B.1.1.519' 'B.1.160' 'B.1.177' 'B.1.221'
#  'B.1.258' 'B.1.367' 'B.1.620' 'Beta' 'Delta' 'Epsilon' 'Eta' 'Gamma'
#  'Iota' 'Kappa' 'Lambda' 'Mu' 'Omicron' 'S:677H.Robin1' 'S:677P.Pelican'
#  'others' 'non_who']
# 24

# %%
#lets visualize the data
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#seperate variants 
omicron = df[df['variant'] == 'Omicron']
delta = df[df['variant'] == 'Delta']
beta = df[df['variant'] == 'Beta']
others = df[(df['variant'] != 'Beta') & (df['variant'] != 'Delta') & (df['variant'] != 'Omicron')]

# %%
others.head(5)
# Out:
#   location        date    variant  num_sequences  perc_sequences  \
# 0   Angola  2020-07-06      Alpha              0             0.0
# 1   Angola  2020-07-06  B.1.1.277              0             0.0
# 2   Angola  2020-07-06  B.1.1.302              0             0.0
# 3   Angola  2020-07-06  B.1.1.519              0             0.0
# 4   Angola  2020-07-06    B.1.160              0             0.0
#
#    num_sequences_total
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# 4                    3

# %%
others.tail(5)
# Out:
#         location        date         variant  num_sequences  perc_sequences  \
# 100410  Zimbabwe  2021-11-01              Mu              0             0.0
# 100412  Zimbabwe  2021-11-01   S:677H.Robin1              0             0.0
# 100413  Zimbabwe  2021-11-01  S:677P.Pelican              0             0.0
# 100414  Zimbabwe  2021-11-01          others              0             0.0
# 100415  Zimbabwe  2021-11-01         non_who              0             0.0
#
#         num_sequences_total
# 100410                    6
# 100412                    6
# 100413                    6
# 100414                    6
# 100415                    6

# %%
#group the above data w.r.t date
omicron_data = omicron.groupby("date").sum()
omicron_data.head(5)
# Out:
#             num_sequences  perc_sequences  num_sequences_total
# date
# 2020-05-11              0             0.0                16436
# 2020-05-25              0             0.0                12903
# 2020-06-08              0             0.0                 9660
# 2020-06-22              0             0.0                16160
# 2020-07-06              0             0.0                15764

# %%
omicron_data["date"] = omicron_data.index
omicron_data.head()
# Out:
#             num_sequences  perc_sequences  num_sequences_total        date
# date
# 2020-05-11              0             0.0                16436  2020-05-11
# 2020-05-25              0             0.0                12903  2020-05-25
# 2020-06-08              0             0.0                 9660  2020-06-08
# 2020-06-22              0             0.0                16160  2020-06-22
# 2020-07-06              0             0.0                15764  2020-07-06

# %%
#similaryly for other variants
delta_data = delta.groupby("date").sum()
delta_data["date"] = delta_data.index
beta_data = beta.groupby("date").sum()
beta_data["date"] = beta_data.index
others_data = others.groupby("date").sum()
others_data["date"] = others_data.index

# %%
plt.figure(figsize = (15,8))
sns.lineplot(x=omicron_data["date"],y=omicron_data["num_sequences"],label="omicron")
sns.lineplot(x=delta_data['date'],y=delta_data['num_sequences'],label='delta')
sns.lineplot(x=beta_data["date"],y=beta_data['num_sequences'],label='beta')
sns.lineplot(x=others_data['date'],y=others_data['num_sequences'],label='others')
plt.xticks(rotation=90)
plt.title('covid cases per day through out the world')
plt.show()

# %%
omicron.head()
# Out:
#     location        date  variant  num_sequences  perc_sequences  \
# 19    Angola  2020-07-06  Omicron              0             0.0
# 43    Angola  2020-08-31  Omicron              0             0.0
# 67    Angola  2020-09-28  Omicron              0             0.0
# 91    Angola  2020-10-12  Omicron              0             0.0
# 115   Angola  2020-10-26  Omicron              0             0.0
#
#      num_sequences_total
# 19                     3
# 43                     1
# 67                    10
# 91                    29
# 115                    7

# %%
omicron_ind = omicron[omicron['location'] == 'India']
np.size(omicron_ind['date'])
# Out:
# 44

# %%
np.size(omicron_ind['date'].unique())
# Out:
# 44

# %%
delta_ind = delta[delta['location'] == "India"]
beta_ind = beta[beta['location']== "India"]
others_ind = others[others['location'] == 'India']
#since others contain different type of variants which may be recorded on same date
others_ind_data = others_ind.groupby("date").sum()

# %%
others_ind_data["date"] = others_ind_data.index
others_ind_data.head()
# Out:
#             num_sequences  perc_sequences  num_sequences_total        date
# date
# 2020-05-11            942           200.0                 9891  2020-05-11
# 2020-05-25           1298           200.0                13629  2020-05-25
# 2020-06-08           1234           200.0                12957  2020-06-08
# 2020-06-22           1532           200.0                16086  2020-06-22
# 2020-07-06            552           200.0                 5796  2020-07-06

# %%
plt.figure(figsize=(15,9))
sns.lineplot(x=omicron_ind["date"],y=omicron_ind["num_sequences"],label="omicron")
sns.lineplot(x=delta_ind["date"],y=delta_ind["num_sequences"],label="delta")
sns.lineplot(x=beta_ind["date"],y=beta_ind["num_sequences"],label="beta")
sns.lineplot(x=others_ind_data["date"],y=others_ind_data["num_sequences"],label="others")
plt.title('covid variants in India')
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(15,9))
sns.lineplot(x=omicron_ind['date'],y=omicron_ind["num_sequences"],label="India")
sns.lineplot(x=omicron_data["date"],y=omicron_data["num_sequences"],label="World")
plt.title('Omicron variant India v/s World')
plt.xticks(rotation=90)
plt.show()

# %%
#to have better view lets plot in log scale
plt.figure(figsize=(15,9))
bx=sns.lineplot(x=omicron_ind['date'],y=omicron_ind["num_sequences"],label="India")
ax = sns.lineplot(x=omicron_data["date"],y=omicron_data["num_sequences"],label="World")
plt.title('Omicron variant India v/s World')
plt.xticks(rotation=90)
ax.set(yscale = "log")
bx.set(yscale = "log")
plt.grid(which='major',linewidth = 0.5)
plt.grid(which='minor',linewidth = 0.5)
plt.show()

# %%
plt.figure(figsize=(15,9))
ax=sns.lineplot(x=delta_ind['date'],y=delta_ind["num_sequences"],label="India")
bx=sns.lineplot(x=delta_data["date"],y=delta_data["num_sequences"],label="World")
plt.title('Delta variant India v/s World')
plt.xticks(rotation=60)
ax.set(yscale='log')
plt.grid(which='major',linewidth=0.5)
plt.grid(which='minor',linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(15,9))
ax=sns.lineplot(x=beta_ind['date'],y=beta_ind["num_sequences"],label="India")
bx=sns.lineplot(x=beta_data["date"],y=beta_data["num_sequences"],label="World")
plt.title('Beta variant India v/s World')
plt.xticks(rotation=60)
ax.set(yscale='log')
plt.grid(which='major',linewidth=0.5)
plt.grid(which='minor',linewidth=0.5)
plt.show()
